# %%
#if else 

marks = int(input("Enter Marks"))

if marks >= 90 and marks <= 100:
    print("A Grade")
elif marks >= 80 and marks <90:
    print("B Grade")
elif marks >= 70 and marks <80:
    print("B Grade")
elif marks >= 60 and marks <70:
    print("B Grade")
elif marks >= 50 and marks <60:
    print("B Grade")
elif marks <=49 and marks >0:
    print("Fail")
else:
    print("Invalid Marks")
# Out:
# A Grade

# %%
#MATCH CASE

x = int(input("Enter a Number"))

match x:
    case x if x>0:
        print(f"{x} is positive")
    case x if x<0:
        print(f"{x} is negative")
    case x if x==0:
        print(f"{x} is Zero")
    case _:
        print("Invalid")
# Out:
# 10 is positive

# %%
x = input("Enter a Number")

match x:
    case 'A':
        print("marks range 90-100")
    case 'B':
        print("marks range 80-90")
    case 'C':
        print("marks range 70-80")
    case 'D':
        print("marks range 60-70")
    case 'E':
        print("marks range 50-60")
    case 'F':
        print("marks range 0-49")
    case 'a':
        print("marks range 90-100")
    case 'b':
        print("marks range 80-90")
    case 'c':
        print("marks range 70-80")
    case 'd':
        print("marks range 60-70")
    case 'e':
        print("marks range 50-60")
    case 'f':
        print("marks range 0-49")
    case _:
        print("invalid grade ")
# Out:
# marks range 90-100

# %%
#Check is a given number is even or odd 
import math

n = int(input("Enter a number"))
x = n/10
y = x - math.floor(x)
if y == 0.0 or y == 0.2 or y == 0.4 or y == 0.6 or y == 0.8:
    print("Even")
else:
    print("odd")
# Out:
# Even

# %%
#check if the given number in even or odd without using modulo function

num = int(input("Enter a number"))
if((num//2)*2) == num:
    print("Even")
else:
    print("Odd")
# Out:
# Odd
